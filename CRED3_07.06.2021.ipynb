# %%
from astropy.io import fits
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import linregress

# %% [markdown]
# ### DARK images (shutter on)
#
# #### framrate = 50fps, readout-mode = CDS, bias correction = ON
# #### sensor temperature = 33°C

# %% [markdown]
# # High gain

# %%
cube_1 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_0.0498ms.fit')
cube_2 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_0.999ms.fit')
cube_3 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_1.999ms.fit')
cube_4 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_2.999ms.fit')
cube_5 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_3.998ms.fit')
cube_6 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_4.998ms.fit')
cube_7 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_5.998ms.fit')
cube_8 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_6.998ms.fit')
cube_9 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_7.998ms.fit')
cube_10 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_8.998ms.fit')
cube_11 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_9.998ms.fit')
cube_12 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_10.998ms.fit')
cube_13 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_12.000ms.fit')
cube_14 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_12.997ms.fit')
cube_15 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_13.997ms.fit')
cube_16 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_14.997ms.fit')
cube_17 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_15.997ms.fit')
cube_18 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_16.997ms.fit')
cube_19 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_17.997ms.fit')
cube_20 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_19.000ms.fit')
cube_21 = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_19.995ms.fit')

# %%
mean_1 = np.mean(cube_1, axis=0)
mean_2 = np.mean(cube_2, axis=0)
mean_3 = np.mean(cube_3, axis=0)
mean_4 = np.mean(cube_4, axis=0)
mean_5 = np.mean(cube_5, axis=0)
mean_6 = np.mean(cube_6, axis=0)
mean_7 = np.mean(cube_7, axis=0)
mean_8 = np.mean(cube_8, axis=0)
mean_9 = np.mean(cube_9, axis=0)
mean_10 = np.mean(cube_10, axis=0)
mean_11 = np.mean(cube_11, axis=0)
mean_12 = np.mean(cube_12, axis=0)
mean_13 = np.mean(cube_13, axis=0)
mean_14 = np.mean(cube_14, axis=0)
mean_15 = np.mean(cube_15, axis=0)
mean_16 = np.mean(cube_16, axis=0)
mean_17 = np.mean(cube_17, axis=0)
mean_18 = np.mean(cube_18, axis=0)
mean_19 = np.mean(cube_19, axis=0)
mean_20 = np.mean(cube_20, axis=0)
mean_21 = np.mean(cube_21, axis=0)

# %%
var_1 = np.var(cube_1, axis=0)
var_2 = np.var(cube_2, axis=0)
var_3 = np.var(cube_3, axis=0)
var_4 = np.var(cube_4, axis=0)
var_5 = np.var(cube_5, axis=0)
var_6 = np.var(cube_6, axis=0)
var_7 = np.var(cube_7, axis=0)
var_8 = np.var(cube_8, axis=0)
var_9 = np.var(cube_9, axis=0)
var_10 = np.var(cube_10, axis=0)
var_11 = np.var(cube_11, axis=0)
var_12 = np.var(cube_12, axis=0)
var_13 = np.var(cube_13, axis=0)
var_14 = np.var(cube_14, axis=0)
var_15 = np.var(cube_15, axis=0)
var_16 = np.var(cube_16, axis=0)
var_17 = np.var(cube_17, axis=0)
var_18 = np.var(cube_18, axis=0)
var_19 = np.var(cube_19, axis=0)
var_20 = np.var(cube_20, axis=0)
var_21 = np.var(cube_21, axis=0)

# %% [markdown]
# #### Mean vs. int time

# %%
mean_arr = np.array([ np.median(mean_1), np.median(mean_2), np.median(mean_3), np.median(mean_4), 
                    np.median(mean_5), np.median(mean_6), np.median(mean_7), np.median(mean_8), 
                    np.median(mean_9), np.median(mean_10), np.median(mean_11), np.median(mean_12), 
                    np.median(mean_13), np.median(mean_14), np.median(mean_15), np.median(mean_16), 
                    np.median(mean_17), np.median(mean_18), np.median(mean_19), np.median(mean_20), 
                    np.median(mean_21)])
tint = np.array([0.05, 1.00, 2.00, 3.00, 4.00, 5.00, 6.00, 7.00, 8.00, 9.00, 10.00, 
                11.00, 12.00, 13.00, 14.00, 15.00, 16.00, 17.00, 18.00, 19.00, 20.00])
line = linregress(tint, mean_arr)
plt.plot(tint, mean_arr, 'o', label='original data')
plt.plot(tint, line.intercept + line.slope*tint, 'r', label='fitted line')
plt.ylabel('mean flux [ADU]')
plt.xlabel('tint [ms]')
plt.legend()
print('slope = %s [ADU/ms]'%line.slope)
# Out:
# slope = 343.20857598434577 [ADU/ms]

# %% [markdown]
# #### Variance vs. int time

# %%
var_arr = np.array([ np.median(var_1), np.median(var_2), np.median(var_3), np.median(var_4), 
                    np.median(var_5), np.median(var_6), np.median(var_7), np.median(var_8), 
                    np.median(var_9), np.median(var_10), np.median(var_11), np.median(var_12), 
                    np.median(var_13), np.median(var_14), np.median(var_15), np.median(var_16), 
                    np.median(var_17), np.median(var_18), np.median(var_19), np.median(var_20), 
                    np.median(var_21)])
tint = np.array([0.05, 1.00, 2.00, 3.00, 4.00, 5.00, 6.00, 7.00, 8.00, 9.00, 10.00, 
                11.00, 12.00, 13.00, 14.00, 15.00, 16.00, 17.00, 18.00, 19.00, 20.00])
line = linregress(tint, var_arr)
plt.plot(tint, var_arr, 'o', label='original data')
plt.plot(tint, line.intercept + line.slope*tint, 'r', label='fitted line')
plt.ylabel('variance [ADU\u00b2]')
plt.xlabel('tint [ms]')
plt.legend()
print('slope = %s [ADU\u00b2/ms]'%line.slope)
# Out:
# slope = 133.56030412423638 [ADU²/ms]

# %% [markdown]
# #### Variance vs. mean

# %%
line = linregress(mean_arr, var_arr)
plt.plot(mean_arr, var_arr, 'o', label='original data')
plt.plot(mean_arr, line.intercept + line.slope*mean_arr, 'r', label='fitted line')
plt.ylabel('variance [ADU\u00b2]')
plt.xlabel('mean flux [ADU]')
plt.legend()
print('1/slope = %s 1/[ADU]'%(1/line.slope))
# Out:
# 1/slope = 2.60105907845856 1/[ADU]

# %% [markdown]
# ### Gain Calculation

# %% [markdown]
# #### Variance vs. mean

# %%
x = np.arange(0, cube_1.shape[0])
y = np.arange(0, cube_1.shape[1])
gain = np.zeros((len(x),len(y)))
for i in x:
    for j in y:
        var_arr = np.array([var_1[i,j], var_2[i,j], var_3[i,j], var_4[i,j], var_5[i,j], var_6[i,j], 
                            var_7[i,j], var_8[i,j], var_9[i,j], var_10[i,j], var_11[i,j], var_12[i,j], 
                            var_13[i,j], var_14[i,j], var_15[i,j], var_16[i,j], var_17[i,j], var_18[i,j], 
                            var_19[i,j], var_20[i,j], var_21[i,j]])
        mean_arr = np.array([mean_1[i,j], mean_2[i,j], mean_3[i,j], mean_4[i,j], mean_5[i,j], mean_6[i,j], 
                            mean_7[i,j], mean_8[i,j], mean_9[i,j], mean_10[i,j], mean_11[i,j], mean_12[i,j], 
                            mean_13[i,j], mean_14[i,j], mean_15[i,j], mean_16[i,j], mean_17[i,j], mean_18[i,j], 
                            mean_19[i,j], mean_20[i,j], mean_21[i,j]])
        res = linregress(mean_arr, var_arr)
        m = res.slope
        gain[i,j] = 1/m

# %%
plt.hist(gain.flat, bins=np.arange(0, 6, 0.5))
# Out:
# (array([2.0000e+01, 3.0000e+01, 7.6000e+01, 1.4960e+03, 2.3077e+04,
#         2.2502e+04, 2.5170e+03, 4.0300e+02, 3.1800e+02, 1.0100e+02,
#         2.7000e+01]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5]),
#  <BarContainer object of 11 artists>)

# %%
gain = np.median(gain, axis = None)
print('Gain = %s e-/ADU'%(gain))
# Out:
# Gain = 2.5118383390812804 e-/ADU

# %% [markdown]
# ### Readout noise

# %%
bias_img = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_0.0498ms_biasimg.fit')
var = np.var(bias_img, axis=0)
ron = np.sqrt(np.median(var)) # in ADU
ron = ron*gain # in e-
print('Readout noise = %s e-'%(ron))
# Out:
# Readout noise = 27.35311220644996 e-

# %% [markdown]
# ### Mean noise at 2ms

# %%
cube = fits.getdata('G:/CRED3/20210607/50fps/high-gain/20210307_50fps_1.999ms.fit')
std = np.sqrt(np.var(cube, axis=0))
std = std*gain
print('Mean noise = %s e-'%(np.mean(std)))
# Out:
# Mean noise = 55.857654545906634 e-

# %% [markdown]
# # Medium gain

# %%
cube_1 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_0.0499ms.fits')
cube_2 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_0.999ms.fits')
cube_3 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_1.999ms.fits')
cube_4 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_2.999ms.fits')
cube_5 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_3.998ms.fits')
cube_6 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_4.998ms.fits')
cube_7 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_5.998ms.fits')
cube_8 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_6.998ms.fits')
cube_9 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_7.998ms.fits')
cube_10 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_8.999ms.fits')
cube_11 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_9.998ms.fits')
cube_12 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_10.998ms.fits')
cube_13 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_11.998ms.fits')
cube_14 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_12.997ms.fits')
cube_15 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_13.997ms.fits')
cube_16 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_14.997ms.fits')
cube_17 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_15.997ms.fits')
cube_18 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_16.997ms.fits')
cube_19 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_17.997ms.fits')
cube_20 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_19.000ms.fits')
cube_21 = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_19.995ms.fits')

# %%
mean_1 = np.mean(cube_1, axis=0)
mean_2 = np.mean(cube_2, axis=0)
mean_3 = np.mean(cube_3, axis=0)
mean_4 = np.mean(cube_4, axis=0)
mean_5 = np.mean(cube_5, axis=0)
mean_6 = np.mean(cube_6, axis=0)
mean_7 = np.mean(cube_7, axis=0)
mean_8 = np.mean(cube_8, axis=0)
mean_9 = np.mean(cube_9, axis=0)
mean_10 = np.mean(cube_10, axis=0)
mean_11 = np.mean(cube_11, axis=0)
mean_12 = np.mean(cube_12, axis=0)
mean_13 = np.mean(cube_13, axis=0)
mean_14 = np.mean(cube_14, axis=0)
mean_15 = np.mean(cube_15, axis=0)
mean_16 = np.mean(cube_16, axis=0)
mean_17 = np.mean(cube_17, axis=0)
mean_18 = np.mean(cube_18, axis=0)
mean_19 = np.mean(cube_19, axis=0)
mean_20 = np.mean(cube_20, axis=0)
mean_21 = np.mean(cube_21, axis=0)

# %%
var_1 = np.var(cube_1, axis=0)
var_2 = np.var(cube_2, axis=0)
var_3 = np.var(cube_3, axis=0)
var_4 = np.var(cube_4, axis=0)
var_5 = np.var(cube_5, axis=0)
var_6 = np.var(cube_6, axis=0)
var_7 = np.var(cube_7, axis=0)
var_8 = np.var(cube_8, axis=0)
var_9 = np.var(cube_9, axis=0)
var_10 = np.var(cube_10, axis=0)
var_11 = np.var(cube_11, axis=0)
var_12 = np.var(cube_12, axis=0)
var_13 = np.var(cube_13, axis=0)
var_14 = np.var(cube_14, axis=0)
var_15 = np.var(cube_15, axis=0)
var_16 = np.var(cube_16, axis=0)
var_17 = np.var(cube_17, axis=0)
var_18 = np.var(cube_18, axis=0)
var_19 = np.var(cube_19, axis=0)
var_20 = np.var(cube_20, axis=0)
var_21 = np.var(cube_21, axis=0)

# %% [markdown]
# #### Mean vs. int time

# %%
mean_arr = np.array([ np.median(mean_1), np.median(mean_2), np.median(mean_3), np.median(mean_4), 
                    np.median(mean_5), np.median(mean_6), np.median(mean_7), np.median(mean_8), 
                    np.median(mean_9), np.median(mean_10), np.median(mean_11), np.median(mean_12), 
                    np.median(mean_13), np.median(mean_14), np.median(mean_15), np.median(mean_16), 
                    np.median(mean_17), np.median(mean_18), np.median(mean_19), np.median(mean_20), 
                    np.median(mean_21)])
tint = np.array([0.05, 1.00, 2.00, 3.00, 4.00, 5.00, 6.00, 7.00, 8.00, 9.00, 10.00, 
                11.00, 12.00, 13.00, 14.00, 15.00, 16.00, 17.00, 18.00, 19.00, 20.00])
line = linregress(tint, mean_arr)
plt.plot(tint, mean_arr, 'o', label='original data')
plt.plot(tint, line.intercept + line.slope*tint, 'r', label='fitted line')
plt.ylabel('mean flux [ADU]')
plt.xlabel('tint [ms]')
plt.legend()
print('slope = %s [ADU/ms]'%line.slope)
# Out:
# slope = 90.95301362928468 [ADU/ms]

# %% [markdown]
# #### Variance vs. int time

# %%
var_arr = np.array([ np.median(var_1), np.median(var_2), np.median(var_3), np.median(var_4), 
                    np.median(var_5), np.median(var_6), np.median(var_7), np.median(var_8), 
                    np.median(var_9), np.median(var_10), np.median(var_11), np.median(var_12), 
                    np.median(var_13), np.median(var_14), np.median(var_15), np.median(var_16), 
                    np.median(var_17), np.median(var_18), np.median(var_19), np.median(var_20), 
                    np.median(var_21)])
tint = np.array([0.05, 1.00, 2.00, 3.00, 4.00, 5.00, 6.00, 7.00, 8.00, 9.00, 10.00, 
                11.00, 12.00, 13.00, 14.00, 15.00, 16.00, 17.00, 18.00, 19.00, 20.00])
line = linregress(tint, var_arr)
plt.plot(tint, var_arr, 'o', label='original data')
plt.plot(tint, line.intercept + line.slope*tint, 'r', label='fitted line')
plt.ylabel('variance [ADU\u00b2]')
plt.xlabel('tint [ms]')
plt.legend()
print('slope = %s [ADU\u00b2/ms]'%line.slope)
# Out:
# slope = 10.50002208953468 [ADU²/ms]

# %% [markdown]
# #### Variance vs. mean

# %%
line = linregress(mean_arr, var_arr)
plt.plot(mean_arr, var_arr, 'o', label='original data')
plt.plot(mean_arr, line.intercept + line.slope*mean_arr, 'r', label='fitted line')
plt.ylabel('variance [ADU\u00b2]')
plt.xlabel('mean flux [ADU]')
plt.legend()
print('1/slope = %s 1/[ADU]'%(1/line.slope))
# Out:
# 1/slope = 8.732224123025143 1/[ADU]

# %% [markdown]
# ### Gain Calculation

# %% [markdown]
# #### Variance vs. mean

# %%
x = np.arange(0, cube_1.shape[0])
y = np.arange(0, cube_1.shape[1])
gain = np.zeros((len(x),len(y)))
for i in x:
    for j in y:
        var_arr = np.array([var_1[i,j], var_2[i,j], var_3[i,j], var_4[i,j], var_5[i,j], var_6[i,j], 
                            var_7[i,j], var_8[i,j], var_9[i,j], var_10[i,j], var_11[i,j], var_12[i,j], 
                            var_13[i,j], var_14[i,j], var_15[i,j], var_16[i,j], var_17[i,j], var_18[i,j], 
                            var_19[i,j], var_20[i,j], var_21[i,j]])
        mean_arr = np.array([mean_1[i,j], mean_2[i,j], mean_3[i,j], mean_4[i,j], mean_5[i,j], mean_6[i,j], 
                            mean_7[i,j], mean_8[i,j], mean_9[i,j], mean_10[i,j], mean_11[i,j], mean_12[i,j], 
                            mean_13[i,j], mean_14[i,j], mean_15[i,j], mean_16[i,j], mean_17[i,j], mean_18[i,j], 
                            mean_19[i,j], mean_20[i,j], mean_21[i,j]])
        res = linregress(mean_arr, var_arr)
        m = res.slope
        gain[i,j] = 1/m

# %%
plt.hist(gain.flat, bins=np.arange(0, 15, 0.5))
# Out:
# (array([1.0000e+00, 7.0000e+00, 5.0000e+00, 7.0000e+00, 1.0000e+01,
#         3.0000e+00, 1.4000e+01, 1.7000e+01, 2.1000e+01, 3.4000e+01,
#         5.3000e+01, 1.5300e+02, 4.8000e+02, 1.5230e+03, 4.0580e+03,
#         7.5920e+03, 1.0260e+04, 1.0088e+04, 7.7410e+03, 4.6660e+03,
#         2.2590e+03, 9.6600e+02, 4.1100e+02, 1.3900e+02, 5.1000e+01,
#         1.4000e+01, 5.0000e+00, 1.0000e+00, 0.0000e+00]),
#  array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#          5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#         11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5]),
#  <BarContainer object of 29 artists>)

# %%
gain = np.median(gain, axis = None)
print('Gain = %s e-/ADU'%(gain))
# Out:
# Gain = 8.535583511494107 e-/ADU

# %% [markdown]
# ### Readout noise

# %%
bias_img = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210307_50fps_0.0498ms_biasimg.fits')
var = np.var(bias_img, axis=0)
ron = np.sqrt(np.median(var)) # in ADU
ron = ron*gain # in e-
print('Readout noise = %s e-'%(ron))
# Out:
# Readout noise = 46.0497696926578 e-

# %% [markdown]
# ### Mean noise at 2ms

# %%
cube = fits.getdata('G:/CRED3/20210607/50fps/med-gain/20210607_50fps_1.999ms.fits')
std = np.sqrt(np.var(cube, axis=0))
std = std*gain
print('Mean noise = %s e-'%(np.mean(std)))
# Out:
# Mean noise = 65.18760715590773 e-

# %% [markdown]
# # Low gain

# %%
cube_1 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_0.0498ms.fit')
cube_2 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_0.999ms.fit')
cube_3 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_1.999ms.fit')
cube_4 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_2.999ms.fit')
cube_5 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_3.998ms.fit')
cube_6 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_4.998ms.fit')
cube_7 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_5.998ms.fit')
cube_8 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_6.998ms.fit')
cube_9 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_7.998ms.fit')
cube_10 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_8.998ms.fit')
cube_11 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_9.998ms.fit')
cube_12 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_10.998ms.fit')
cube_13 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_11.998ms.fit')
cube_14 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_12.997ms.fit')
cube_15 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_13.997ms.fit')
cube_16 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_14.997ms.fit')
cube_17 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_15.997ms.fit')
cube_18 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_16.997ms.fit')
cube_19 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_17.997ms.fit')
cube_20 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_19.000ms.fit')
cube_21 = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_19.995ms.fit')

# %%
mean_1 = np.mean(cube_1, axis=0)
mean_2 = np.mean(cube_2, axis=0)
mean_3 = np.mean(cube_3, axis=0)
mean_4 = np.mean(cube_4, axis=0)
mean_5 = np.mean(cube_5, axis=0)
mean_6 = np.mean(cube_6, axis=0)
mean_7 = np.mean(cube_7, axis=0)
mean_8 = np.mean(cube_8, axis=0)
mean_9 = np.mean(cube_9, axis=0)
mean_10 = np.mean(cube_10, axis=0)
mean_11 = np.mean(cube_11, axis=0)
mean_12 = np.mean(cube_12, axis=0)
mean_13 = np.mean(cube_13, axis=0)
mean_14 = np.mean(cube_14, axis=0)
mean_15 = np.mean(cube_15, axis=0)
mean_16 = np.mean(cube_16, axis=0)
mean_17 = np.mean(cube_17, axis=0)
mean_18 = np.mean(cube_18, axis=0)
mean_19 = np.mean(cube_19, axis=0)
mean_20 = np.mean(cube_20, axis=0)
mean_21 = np.mean(cube_21, axis=0)

# %%
var_1 = np.var(cube_1, axis=0)
var_2 = np.var(cube_2, axis=0)
var_3 = np.var(cube_3, axis=0)
var_4 = np.var(cube_4, axis=0)
var_5 = np.var(cube_5, axis=0)
var_6 = np.var(cube_6, axis=0)
var_7 = np.var(cube_7, axis=0)
var_8 = np.var(cube_8, axis=0)
var_9 = np.var(cube_9, axis=0)
var_10 = np.var(cube_10, axis=0)
var_11 = np.var(cube_11, axis=0)
var_12 = np.var(cube_12, axis=0)
var_13 = np.var(cube_13, axis=0)
var_14 = np.var(cube_14, axis=0)
var_15 = np.var(cube_15, axis=0)
var_16 = np.var(cube_16, axis=0)
var_17 = np.var(cube_17, axis=0)
var_18 = np.var(cube_18, axis=0)
var_19 = np.var(cube_19, axis=0)
var_20 = np.var(cube_20, axis=0)
var_21 = np.var(cube_21, axis=0)

# %% [markdown]
# #### Mean vs. int time

# %%
mean_arr = np.array([ np.median(mean_1), np.median(mean_2), np.median(mean_3), np.median(mean_4), 
                    np.median(mean_5), np.median(mean_6), np.median(mean_7), np.median(mean_8), 
                    np.median(mean_9), np.median(mean_10), np.median(mean_11), np.median(mean_12), 
                    np.median(mean_13), np.median(mean_14), np.median(mean_15), np.median(mean_16), 
                    np.median(mean_17), np.median(mean_18), np.median(mean_19), np.median(mean_20), 
                    np.median(mean_21)])
tint = np.array([0.05, 1.00, 2.00, 3.00, 4.00, 5.00, 6.00, 7.00, 8.00, 9.00, 10.00, 
                11.00, 12.00, 13.00, 14.00, 15.00, 16.00, 17.00, 18.00, 19.00, 20.00])
line = linregress(tint, mean_arr)
plt.plot(tint, mean_arr, 'o', label='original data')
plt.plot(tint, line.intercept + line.slope*tint, 'r', label='fitted line')
plt.ylabel('mean flux [ADU]')
plt.xlabel('tint [ms]')
plt.legend()
print('slope = %s [ADU/ms]'%line.slope)
# Out:
# slope = 10.603282917571002 [ADU/ms]

# %% [markdown]
# #### Variance vs. int time

# %%
var_arr = np.array([ np.median(var_1), np.median(var_2), np.median(var_3), np.median(var_4), 
                    np.median(var_5), np.median(var_6), np.median(var_7), np.median(var_8), 
                    np.median(var_9), np.median(var_10), np.median(var_11), np.median(var_12), 
                    np.median(var_13), np.median(var_14), np.median(var_15), np.median(var_16), 
                    np.median(var_17), np.median(var_18), np.median(var_19), np.median(var_20), 
                    np.median(var_21)])
tint = np.array([0.05, 1.00, 2.00, 3.00, 4.00, 5.00, 6.00, 7.00, 8.00, 9.00, 10.00, 
                11.00, 12.00, 13.00, 14.00, 15.00, 16.00, 17.00, 18.00, 19.00, 20.00])
line = linregress(tint, var_arr)
plt.plot(tint, var_arr, 'o', label='original data')
plt.plot(tint, line.intercept + line.slope*tint, 'r', label='fitted line')
plt.ylabel('variance [ADU\u00b2]')
plt.xlabel('tint [ms]')
plt.legend()
print('slope = %s [ADU\u00b2/ms]'%line.slope)
# Out:
# slope = 0.09029407147788882 [ADU²/ms]

# %% [markdown]
# #### Variance vs. mean

# %%
line = linregress(mean_arr, var_arr)
plt.plot(mean_arr, var_arr, 'o', label='original data')
plt.plot(mean_arr, line.intercept + line.slope*mean_arr, 'r', label='fitted line')
plt.ylabel('variance [ADU\u00b2]')
plt.xlabel('mean flux [ADU]')
plt.legend()
print('1/slope = %s 1/[ADU]'%(1/line.slope))
# Out:
# 1/slope = 154.8948528907466 1/[ADU]

# %% [markdown]
# ## Gain Calculation

# %% [markdown]
# #### Variance vs. mean

# %%
x = np.arange(0, cube_1.shape[0])
y = np.arange(0, cube_1.shape[1])
gain = np.zeros((len(x),len(y)))
for i in x:
    for j in y:
        var_arr = np.array([var_1[i,j], var_2[i,j], var_3[i,j], var_4[i,j], var_5[i,j], var_6[i,j], 
                            var_7[i,j], var_8[i,j], var_9[i,j], var_10[i,j], var_11[i,j], var_12[i,j], 
                            var_13[i,j], var_14[i,j], var_15[i,j], var_16[i,j], var_17[i,j], var_18[i,j], 
                            var_19[i,j], var_20[i,j], var_21[i,j]])
        mean_arr = np.array([mean_1[i,j], mean_2[i,j], mean_3[i,j], mean_4[i,j], mean_5[i,j], mean_6[i,j], 
                            mean_7[i,j], mean_8[i,j], mean_9[i,j], mean_10[i,j], mean_11[i,j], mean_12[i,j], 
                            mean_13[i,j], mean_14[i,j], mean_15[i,j], mean_16[i,j], mean_17[i,j], mean_18[i,j], 
                            mean_19[i,j], mean_20[i,j], mean_21[i,j]])
        res = linregress(mean_arr, var_arr)
        m = res.slope
        gain[i,j] = 1/m

# %%
plt.hist(gain.flat, bins=np.arange(0, 400, 5))
# Out:
# (array([4.000e+00, 1.000e+00, 5.000e+00, 8.000e+00, 9.000e+00, 3.100e+01,
#         4.200e+01, 1.240e+02, 2.930e+02, 5.630e+02, 8.580e+02, 1.160e+03,
#         1.394e+03, 1.641e+03, 1.738e+03, 1.818e+03, 1.823e+03, 1.921e+03,
#         1.740e+03, 1.755e+03, 1.657e+03, 1.594e+03, 1.434e+03, 1.264e+03,
#         1.150e+03, 1.082e+03, 1.064e+03, 9.790e+02, 8.890e+02, 8.730e+02,
#         7.600e+02, 6.720e+02, 6.810e+02, 6.470e+02, 5.890e+02, 5.250e+02,
#         5.010e+02, 4.620e+02, 4.700e+02, 4.290e+02, 3.820e+02, 3.720e+02,
#         3.600e+02, 3.110e+02, 3.240e+02, 3.170e+02, 2.990e+02, 2.690e+02,
#         2.640e+02, 2.620e+02, 2.460e+02, 2.410e+02, 2.240e+02, 1.770e+02,
#         1.880e+02, 2.040e+02, 1.720e+02, 1.880e+02, 1.650e+02, 1.560e+02,
#         1.470e+02, 1.230e+02, 1.170e+02, 1.260e+02, 1.260e+02, 1.270e+02,
#         1.220e+02, 1.050e+02, 8.700e+01, 1.190e+02, 1.090e+02, 1.030e+02,
#         9.000e+01, 9.600e+01, 7.900e+01, 8.300e+01, 8.500e+01, 8.500e+01,
# ...

# %%
gain = np.median(gain, axis = None)
print('Gain = %s e-/ADU'%(gain))
# Out:
# Gain = 113.18457291025365 e-/ADU

# %% [markdown]
# ## Readout noise

# %%
bias_img = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_0.0498ms_biasimg.fit')
var = np.var(bias_img, axis=0)
ron = np.sqrt(np.median(var)) # in ADU
ron = ron*gain # in e-
print('Readout noise = %s e-'%(ron))
# Out:
# Readout noise = 363.4811143719388 e-

# %% [markdown]
# ### Mean noise at 2ms

# %%
cube = fits.getdata('G:/CRED3/20210607/50fps/low-gain/20210307_50fps_1.999ms.fit')
std = np.sqrt(np.var(cube, axis=0))
std = std*gain
print('Mean noise = %s e-'%(np.mean(std)))
# Out:
# Mean noise = 370.45172617312835 e-

# %% [markdown]
# ## Results
# |                 | Description            | Units    | Values |
# | :-------------- | :--------------------- | :------: | :----: |
# | **High gain**   | System gain (at 50fps) |  e-/ADU  | 2.51   |
# |                 | Readout noise (at 50μs)|  e-      | 27.35  |
# |                 | Mean noise (at 2ms)    |  e-      | 55.85  |
# | **Medium gain** | System gain (at 50fps) |  e-/ADU  | 8.54   |
# |                 | Readout noise (at 50μs)|  e-      | 46.05  |
# |                 | Mean noise (at 2ms)    |  e-      | 65.19  |
# | **Low gain**    | System gain (at 50fps) |  e-/ADU  | 113.18 |
# |                 | Readout noise (at 50μs)|  e-      | 363.48 |
# |                 | Mean noise (at 2ms)    |  e-      | 370.45 |

# %% [markdown]
# ## Values from CRED-3 test report
# |                 | Description              | Units    | Values |
# | :-------------- | :----------------------- | :------: | :----: |
# | **High gain**   | System gain (at 600fps) |  e-/ADU  | 2.42   |
# |                 | Mean noise (at 50μs)     |  e-      | 45.78  |
# |                 | Mean noise (at 1.66ms)   |  e-      | 54.91  |
# | **Medium gain** | System gain (at 600fps)   |  e-/ADU  | 7.89   |
# |                 | Mean noise (at 1.66ms)   |  e-      | 65.69  |
# | **Low gain**    | System gain (at 600fps)   |  e-/ADU  | 97.04 |
# |                 | Mean noise (at 1.66ms)   |  e-      | 325.25 |
